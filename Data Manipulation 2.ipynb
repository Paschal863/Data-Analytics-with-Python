# %%
import pandas as pd

#importing the data
df = pd.read_excel('KevinCookieCompanyFinancials.xlsx')

df
# Out:
#            Country                        Product  Units Sold  \
# 0           Canada                 Chocolate Chip       292.0
# 1           Mexico                 Chocolate Chip       974.0
# 2           Canada                 Chocolate Chip      2518.0
# 3          Germany                 Chocolate Chip      1006.0
# 4          Germany                 Chocolate Chip       367.0
# ..             ...                            ...         ...
# 695         France  White Chocolate Macadamia Nut      2826.0
# 696         France  White Chocolate Macadamia Nut       663.0
# 697  United States  White Chocolate Macadamia Nut      2574.0
# 698  United States  White Chocolate Macadamia Nut      2438.0
# 699  United States  White Chocolate Macadamia Nut       914.0
#
#      Revenue per cookie  Cost per cookie  Revenue     Cost   Profit  \
# 0                     5             2.00   1460.0   584.00   876.00
# 1                     5             2.00   4870.0  1948.00  2922.00
# ...

# %%
fil_df = df.loc[(df['Country'] == 'France') & (df['Product'] == 'Chocolate Chip') & (df['Revenue'] > 6000)]

fil_df

#filtering data
# Out:
#     Country         Product  Units Sold  Revenue per cookie  Cost per cookie  \
# 15   France  Chocolate Chip      3945.0                   5              2.0
# 16   France  Chocolate Chip      2296.0                   5              2.0
# 26   France  Chocolate Chip      2155.0                   5              2.0
# 35   France  Chocolate Chip      1785.0                   5              2.0
# 43   France  Chocolate Chip      2434.5                   5              2.0
# 45   France  Chocolate Chip      1901.0                   5              2.0
# 51   France  Chocolate Chip      1287.0                   5              2.0
# 55   France  Chocolate Chip      2261.0                   5              2.0
# 61   France  Chocolate Chip      2988.0                   5              2.0
# 73   France  Chocolate Chip      1303.0                   5              2.0
# 75   France  Chocolate Chip      2385.0                   5              2.0
# ...

# %%
#resetting index of filtered data

fil_df.reset_index(drop = True)
# Out:
#    Country         Product  Units Sold  Revenue per cookie  Cost per cookie  \
# 0   France  Chocolate Chip      3945.0                   5              2.0
# 1   France  Chocolate Chip      2296.0                   5              2.0
# 2   France  Chocolate Chip      2155.0                   5              2.0
# 3   France  Chocolate Chip      1785.0                   5              2.0
# 4   France  Chocolate Chip      2434.5                   5              2.0
# 5   France  Chocolate Chip      1901.0                   5              2.0
# 6   France  Chocolate Chip      1287.0                   5              2.0
# 7   France  Chocolate Chip      2261.0                   5              2.0
# 8   France  Chocolate Chip      2988.0                   5              2.0
# 9   France  Chocolate Chip      1303.0                   5              2.0
# 10  France  Chocolate Chip      2385.0                   5              2.0
# ...

# %%
new_df = df[['Revenue', 'Cost', 'Profit']].mean()

new_df

#getting mean of a specific columns
# Out:
# Revenue    6700.357857
# Cost       2752.752464
# Profit     3947.605393
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             700 non-null    object
#  1   Product             700 non-null    object
#  2   Units Sold          700 non-null    float64
#  3   Revenue per cookie  700 non-null    int64
#  4   Cost per cookie     700 non-null    float64
#  5   Revenue             700 non-null    float64
#  6   Cost                700 non-null    float64
#  7   Profit              700 non-null    float64
#  8   Date                700 non-null    datetime64[ns]
#  9   Month Number        700 non-null    int64
#  10  Month Name          700 non-null    object
#  11  Year                700 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(3)
# memory usage: 65.8+ KB

# %%
df.describe()
# Out:
#         Units Sold  Revenue per cookie  Cost per cookie       Revenue  \
# count   700.000000          700.000000       700.000000    700.000000
# mean   1608.294286            4.180000         1.721286   6700.357857
# std     867.427859            1.538872         0.753227   4623.793761
# min     200.000000            1.000000         0.200000    200.000000
# 25%     905.000000            3.000000         1.250000   2854.000000
# 50%    1542.500000            5.000000         2.000000   5871.500000
# 75%    2229.125000            5.000000         2.200000   9580.000000
# max    4492.500000            6.000000         2.750000  23985.000000
#
#                Cost        Profit  Month Number         Year
# count    700.000000    700.000000    700.000000   700.000000
# mean    2752.752464   3947.605393      7.900000  2018.750000
# std     2036.959892   2615.761535      3.377321     0.433322
# min       40.000000    160.000000      1.000000  2018.000000
# ...

# %%
#adding new column

df['15% Tax'] = df['Revenue'] * 0.15

df
# Out:
#            Country                        Product  Units Sold  \
# 0           Canada                 Chocolate Chip       292.0
# 1           Mexico                 Chocolate Chip       974.0
# 2           Canada                 Chocolate Chip      2518.0
# 3          Germany                 Chocolate Chip      1006.0
# 4          Germany                 Chocolate Chip       367.0
# ..             ...                            ...         ...
# 695         France  White Chocolate Macadamia Nut      2826.0
# 696         France  White Chocolate Macadamia Nut       663.0
# 697  United States  White Chocolate Macadamia Nut      2574.0
# 698  United States  White Chocolate Macadamia Nut      2438.0
# 699  United States  White Chocolate Macadamia Nut       914.0
#
#      Revenue per cookie  Cost per cookie  Revenue     Cost   Profit  \
# 0                     5             2.00   1460.0   584.00   876.00
# 1                     5             2.00   4870.0  1948.00  2922.00
# ...

# %%
#rearranging columns

cols = list(df.columns)

new_df = df[cols[0:6] + [cols [-1]] + cols[6:12]] 

df = new_df

new_df
# Out:
#            Country                        Product  Units Sold  \
# 0           Canada                 Chocolate Chip       292.0
# 1           Mexico                 Chocolate Chip       974.0
# 2           Canada                 Chocolate Chip      2518.0
# 3          Germany                 Chocolate Chip      1006.0
# 4          Germany                 Chocolate Chip       367.0
# ..             ...                            ...         ...
# 695         France  White Chocolate Macadamia Nut      2826.0
# 696         France  White Chocolate Macadamia Nut       663.0
# 697  United States  White Chocolate Macadamia Nut      2574.0
# 698  United States  White Chocolate Macadamia Nut      2438.0
# 699  United States  White Chocolate Macadamia Nut       914.0
#
#      Revenue per cookie  Cost per cookie  Revenue  15% Tax     Cost   Profit  \
# 0                     5             2.00   1460.0   219.00   584.00   876.00
# ...

# %%
#sorting values in ascending or descending order

df.sort_values('Revenue')

#df.sort_values('Revenue', ascending = False)
# Out:
#            Country                        Product  Units Sold  \
# 289         Canada                 Fortune Cookie       200.0
# 285         France                 Fortune Cookie       293.0
# 260         France                 Fortune Cookie       322.0
# 265        Germany                 Fortune Cookie       334.0
# 210         Canada                 Fortune Cookie       345.0
# ..             ...                            ...         ...
# 19   United States                 Chocolate Chip      4492.5
# 655         Canada  White Chocolate Macadamia Nut      3793.5
# 613         Canada  White Chocolate Macadamia Nut      3850.5
# 599         France  White Chocolate Macadamia Nut      3864.0
# 681         France  White Chocolate Macadamia Nut      3997.5
#
#      Revenue per cookie  Cost per cookie  Revenue   15% Tax       Cost  \
# 289                   1             0.20    200.0    30.000     40.000
# 285                   1             0.20    293.0    43.950     58.600
# ...

# %%
#Filtering based on textual data

df.loc[df['Product'].str.contains('Chocolate')]
# Out:
#            Country                        Product  Units Sold  \
# 0           Canada                 Chocolate Chip       292.0
# 1           Mexico                 Chocolate Chip       974.0
# 2           Canada                 Chocolate Chip      2518.0
# 3          Germany                 Chocolate Chip      1006.0
# 4          Germany                 Chocolate Chip       367.0
# ..             ...                            ...         ...
# 695         France  White Chocolate Macadamia Nut      2826.0
# 696         France  White Chocolate Macadamia Nut       663.0
# 697  United States  White Chocolate Macadamia Nut      2574.0
# 698  United States  White Chocolate Macadamia Nut      2438.0
# 699  United States  White Chocolate Macadamia Nut       914.0
#
#      Revenue per cookie  Cost per cookie  Revenue  15% Tax     Cost   Profit  \
# 0                     5             2.00   1460.0   219.00   584.00   876.00
# ...

# %%
#groupby (aggregate statistics)

df.groupby(['Country']).mean()
# Out:
#                 Units Sold  Revenue per cookie  Cost per cookie      Revenue  \
# Country
# Canada         1767.346429            4.171429         1.712143  7331.082143
# France         1720.935714            4.142857         1.704286  7218.082143
# Germany        1439.242857            4.185714         1.722857  5993.357143
# Mexico         1452.321429            4.171429         1.717857  5976.192857
# United States  1661.625000            4.228571         1.749286  6983.075000
#
#                    15% Tax         Cost       Profit  Month Number     Year
# Country
# Canada         1099.662321  3000.240893  4330.841250           7.9  2018.75
# France         1082.712321  2967.666071  4250.416071           7.9  2018.75
# Germany         899.003571  2471.916786  3521.440357           7.9  2018.75
# Mexico          896.428929  2441.916071  3534.276786           7.9  2018.75
# United States  1047.461250  2882.022500  4101.052500           7.9  2018.75

# %%
#groupby (aggregate statistics)

df.groupby(['Product']).mean()
# Out:
#                                 Units Sold  Revenue per cookie  \
# Product
# Chocolate Chip                 1674.452970                 5.0
# Fortune Cookie                 1658.043011                 1.0
# Oatmeal Raisin                 1652.287234                 5.0
# Snickerdoodle                  1578.989247                 4.0
# Sugar                          1548.467890                 3.0
# White Chocolate Macadamia Nut  1490.133028                 6.0
#
#                                Cost per cookie      Revenue      15% Tax  \
# Product
# Chocolate Chip                            2.00  8372.264851  1255.839728
# Fortune Cookie                            0.20  1658.043011   248.706452
# Oatmeal Raisin                            2.20  8261.436170  1239.215426
# Snickerdoodle                             1.50  6315.956989   947.393548
# Sugar                                     1.25  4645.403670   696.810550
# ...
