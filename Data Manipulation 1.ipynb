# %%
import pandas as pd
#importing the data file

df = pd.read_excel('supermarket_sales.xlsx')

df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#to drop a specific column

new_df = df.drop(columns = 'City')

new_df
# Out:
#       Invoice ID Branch Customer type  Gender            Product line  \
# 0    750-67-8428      A        Member  Female       Health and beauty
# 1    226-31-3081      C        Normal  Female  Electronic accessories
# 2    631-41-3108      A        Normal    Male      Home and lifestyle
# 3    123-19-1176      A        Member    Male       Health and beauty
# 4    373-73-7910      A        Normal    Male       Sports and travel
# ..           ...    ...           ...     ...                     ...
# 995  233-67-5758      C        Normal    Male       Health and beauty
# 996  303-96-2227      B        Normal  Female      Home and lifestyle
# 997  727-02-1313      A        Member    Male      Food and beverages
# 998  347-56-2442      A        Normal    Male      Home and lifestyle
# 999  849-09-3807      A        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date      Time  \
# ...

# %%
#to read a specified row

df.iloc[999]
# Out:
# Invoice ID                         849-09-3807
# Branch                                       A
# City                                    Yangon
# Customer type                           Member
# Gender                                  Female
# Product line               Fashion accessories
# Unit price                               88.34
# Quantity                                     7
# Tax 5%                                  30.919
# Total                                  649.299
# Date                       2019-02-18 00:00:00
# Time                                  13:28:00
# Payment                                   Cash
# cogs                                    618.38
# gross margin percentage               4.761905
# gross income                            30.919
# Rating                                     6.6
# Name: 999, dtype: object

# %%
#to read a specific location

new_df = df.iloc[0:4]

new_df
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# 1  10:29:00         Cash   76.40                 4.761905        3.8200
# 2  13:23:00  Credit card  324.31                 4.761905       16.2155
# ...

# %%
#adding new columns- 'Tax 10%'

df['Tax 10%'] = df['cogs'] * 0.1

df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#rearranging columns - moving the 'Tax 10%' column next to the 'Tax 5%'

cols = list(df.columns)

df = df[cols[0:9] + [cols[-1]] + cols[9:17]]

df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%  Tax 10%  \
# 0         Health and beauty       74.69         7  26.1415   52.283
# 1    Electronic accessories       15.28         5   3.8200    7.640
# 2        Home and lifestyle       46.33         7  16.2155   32.431
# ...

# %%
#filtering data

new_df = df.loc[(df['Gender'] == 'Male') & (df['City'] == 'Yangon') & (df['Unit price'] > 50)]

#not containing, use (~)

#new_df = df.loc[~(df['Gender'] == 'Male') & ~(df['City'] == 'Yangon') & (df['Unit price'] > 50)]
                                   
new_df
# Out:
#       Invoice ID Branch    City Customer type Gender            Product line  \
# 3    123-19-1176      A  Yangon        Member   Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal   Male       Sports and travel
# 17   765-26-6951      A  Yangon        Normal   Male       Sports and travel
# 18   329-62-1586      A  Yangon        Normal   Male      Food and beverages
# 24   549-59-1358      A  Yangon        Member   Male       Sports and travel
# ..           ...    ...     ...           ...    ...                     ...
# 967  195-06-0432      A  Yangon        Member   Male      Home and lifestyle
# 973  531-56-4728      A  Yangon        Normal   Male      Home and lifestyle
# 981  809-46-1866      A  Yangon        Normal   Male       Health and beauty
# 992  745-74-0715      A  Yangon        Normal   Male  Electronic accessories
# 998  347-56-2442      A  Yangon        Normal   Male      Home and lifestyle
#
# ...

# %%
#resetting index

new_df.reset_index()
# Out:
#      index   Invoice ID Branch    City Customer type Gender  \
# 0        3  123-19-1176      A  Yangon        Member   Male
# 1        4  373-73-7910      A  Yangon        Normal   Male
# 2       17  765-26-6951      A  Yangon        Normal   Male
# 3       18  329-62-1586      A  Yangon        Normal   Male
# 4       24  549-59-1358      A  Yangon        Member   Male
# ..     ...          ...    ...     ...           ...    ...
# 96     967  195-06-0432      A  Yangon        Member   Male
# 97     973  531-56-4728      A  Yangon        Normal   Male
# 98     981  809-46-1866      A  Yangon        Normal   Male
# 99     992  745-74-0715      A  Yangon        Normal   Male
# 100    998  347-56-2442      A  Yangon        Normal   Male
#
#                Product line  Unit price  Quantity   Tax 5%  Tax 10%     Total  \
# 0         Health and beauty       58.22         8  23.2880   46.576  489.0480
# 1         Sports and travel       86.31         7  30.2085   60.417  634.3785
# ...

# %%
#filtering base on texual pattern

df.loc[df['City'].str.contains ('gon')]
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
#aggregate statistics (group by)

df.groupby(['Product line']).mean().sort_values(['gross income'])
# Out:
#                         Unit price  Quantity     Tax 5%    Tax 10%  \
# Product line
# Fashion accessories      57.153652  5.067416  14.528062  29.056124
# Electronic accessories   53.551588  5.711765  15.220597  30.441194
# Food and beverages       56.008851  5.471264  15.365310  30.730621
# Health and beauty        54.854474  5.618421  15.411572  30.823145
# Sports and travel        56.993253  5.542169  15.812630  31.625259
# Home and lifestyle       55.316937  5.693750  16.030331  32.060662
#
#                              Total        cogs  gross margin percentage  \
# Product line
# Fashion accessories     305.089298  290.561236                 4.761905
# Electronic accessories  319.632538  304.411941                 4.761905
# Food and beverages      322.671517  307.306207                 4.761905
# Health and beauty       323.643020  308.231447                 4.761905
# Sports and travel       332.065220  316.252590                 4.761905
# ...

# %%
df.groupby(['Product line']).sum().sort_values(['gross income'])
# Out:
#                         Unit price  Quantity     Tax 5%   Tax 10%       Total  \
# Product line
# Health and beauty          8337.88       854  2342.5590  4685.118  49193.7390
# Home and lifestyle         8850.71       911  2564.8530  5129.706  53861.9130
# Fashion accessories       10173.35       902  2585.9950  5171.990  54305.8950
# Electronic accessories     9103.77       971  2587.5015  5175.003  54337.5315
# Sports and travel          9460.88       920  2624.8965  5249.793  55122.8265
# Food and beverages         9745.54       952  2673.5640  5347.128  56144.8440
#
#                             cogs  gross margin percentage  gross income  \
# Product line
# Health and beauty       46851.18               723.809524     2342.5590
# Home and lifestyle      51297.06               761.904762     2564.8530
# Fashion accessories     51719.90               847.619048     2585.9950
# Electronic accessories  51750.03               809.523810     2587.5015
# ...
